# %%
import pandas as pd
import numpy as np
import math

# %%
df = pd.read_csv("result_uni.csv")

# %%
df
# Out:
#      id                       name                description  \
# 0     1    Uninterested Unicorn #1    Uninterested Unicorn #1
# 1    10   Uninterested Unicorn #10   Uninterested Unicorn #10
# 2   100  Uninterested Unicorn #100  Uninterested Unicorn #100
# 3    11   Uninterested Unicorn #11   Uninterested Unicorn #11
# 4    12   Uninterested Unicorn #12   Uninterested Unicorn #12
# ..  ...                        ...                        ...
# 95   95   Uninterested Unicorn #95   Uninterested Unicorn #95
# 96   96   Uninterested Unicorn #96   Uninterested Unicorn #96
# 97   97   Uninterested Unicorn #97   Uninterested Unicorn #97
# 98   98   Uninterested Unicorn #98   Uninterested Unicorn #98
# 99   99   Uninterested Unicorn #99   Uninterested Unicorn #99
#
#                                                 image             Accessory  \
# 0   https://uunicorns.mypinata.cloud/ipfs/QmdN73o6...                  Ring
# 1   https://uunicorns.mypinata.cloud/ipfs/QmZRHz6s...       Silver Ear Ring
# 2   https://uunicorns.mypinata.cloud/ipfs/QmYZx7Aq...       Silver Ear Ring
# 3   https://uunicorns.mypinata.cloud/ipfs/QmYoStWc...            Small Ring
# 4   https://uunicorns.mypinata.cloud/ipfs/QmRZAjmG...                  Ring
# ..                                                ...                   ...
# 95  https://uunicorns.mypinata.cloud/ipfs/QmV8h99e...                  Ring
# 96  https://uunicorns.mypinata.cloud/ipfs/QmWbUMup...                  Ring
# 97  https://uunicorns.mypinata.cloud/ipfs/QmW1skR9...  1 Dark Caged Blinker
# 98  https://uunicorns.mypinata.cloud/ipfs/QmcdPC7S...   2 Light Eagle Wings
# 99  https://uunicorns.mypinata.cloud/ipfs/QmbDdqH2...                   NaN
#
#    Background  Beard Body Tattoo         Braid           Chest  ...  \
# 0      Common    NaN         NaN           NaN       Traveller  ...
# 1      Common    NaN         NaN           NaN             NaN  ...
# 2   Pink Fire    NaN         NaN           NaN           Mummy  ...
# 3      Common    NaN         NaN           NaN        Assassin  ...
# 4      Common  Short         NaN           NaN             NaN  ...
# ..        ...    ...         ...           ...             ...  ...
# 95     Common   Long         NaN           NaN         Valiant  ...
# 96     Common    NaN         NaN  Purple Braid       Robinhood  ...
# 97     Common    NaN         NaN           NaN             NaN  ...
# 98     Common    NaN         NaN           NaN    Light Knight  ...
# 99     Common    NaN         NaN  Purple Braid  Grey Chainmail  ...
#
#             Mouth            Neck Neck Tattoo Necklace       Pattern  \
# 0               O   Leather Wraps         NaN      NaN           NaN
# 1   Droopy Tongue             NaN         NaN      NaN     Cracked 1
# 2            Lost             NaN         NaN      NaN      Skeleton
# 3          Closed  Assassin Wraps         NaN      NaN           NaN
# 4          Closed             NaN         NaN      NaN           NaN
# ..            ...             ...         ...      ...           ...
# 95         Closed             NaN         NaN      NaN           NaN
# 96         Closed             NaN         NaN      NaN           NaN
# 97         Closed             NaN         NaN      NaN           NaN
# 98         Closed             NaN         NaN      NaN  Dark Cheetah
# 99         Closed             NaN         NaN      NaN           NaN
#
#                   Shoulder Skin Colour          Special Tattoo     Weapon
# 0              Black Pearl        Cyan              NaN    NaN     Katana
# 1                      NaN         Jam              NaN    NaN        NaN
# 2                      NaN       Green              NaN    NaN        NaN
# 3              Black Pearl        Rose              NaN  Kunai  Nunchucks
# 4                      NaN        Blue              NaN  Kunai        NaN
# ..                     ...         ...              ...    ...        ...
# 95                     NaN     Crimson              NaN    NaN   Baguette
# 96                     NaN      Butter              NaN    NaN     Shield
# 97                     NaN        Blue              NaN    NaN    Chopper
# 98  Light Paladin Pauldron       Choco  Commander Chest    NaN    Chopper
# 99                     NaN        Rose              NaN    NaN        Bow
#
# [100 rows x 31 columns]

# %%
df = df.melt(id_vars=["id","name","description","image"], 
        var_name="trait_type", 
        value_name="value")

# %%
df = df[["id","trait_type","value"]]

# %%
total = df['id'].nunique()

# %%
df.head()
# Out:
#     id trait_type            value
# 0    1  Accessory             Ring
# 1   10  Accessory  Silver Ear Ring
# 2  100  Accessory  Silver Ear Ring
# 3   11  Accessory       Small Ring
# 4   12  Accessory             Ring

# %%
count_list = df.groupby(["trait_type", "value"]).count()

# %%
count_list.reset_index(inplace=True)

# %%
count_list
# Out:
#     trait_type                   value  count  rarity  weight
# 0    Accessory    1 Dark Caged Blinker      1     NaN       1
# 1    Accessory   1 Light Caged Blinker      4     NaN       1
# 2    Accessory  2 Light Caged Blinkers      1     NaN       1
# 3    Accessory     2 Light Eagle Wings      2     NaN       1
# 4    Accessory                Bio Chip      2     NaN       1
# ..         ...                     ...    ...     ...     ...
# 251     Weapon             Moonslasher      1     NaN       1
# 252     Weapon               Nunchucks      5     NaN       1
# 253     Weapon                  Quiver      4     NaN       1
# 254     Weapon                  Shield     10     NaN       1
# 255     Weapon             Steel Staff      3     NaN       1
#
# [256 rows x 5 columns]

# %%
count_list.rename(columns={'id': 'count'}, inplace=True)

# %%
#count_list['value'] = count_list.index
#count_list.reset_index(drop=True, inplace=True)
#count_list = count_list[['trait_type','value']]

# %%
count_list['rarity'] = np.nan
count_list['weight'] = 1

# %%
for index in range(0, len(count_list)):
    if(str(count_list.iloc[index]['value']) == 'nan'):
        continue
    else:
        count_list.at[index,'rarity'] = (total/count_list.iloc[index]['count'])*count_list.iloc[index]['weight']

    
count_list['rarity'] = count_list['rarity'].astype('float64').round(2)

# %%
count_list
# Out:
#     trait_type                   value  count  rarity  weight
# 0    Accessory    1 Dark Caged Blinker      1  100.00       1
# 1    Accessory   1 Light Caged Blinker      4   25.00       1
# 2    Accessory  2 Light Caged Blinkers      1  100.00       1
# 3    Accessory     2 Light Eagle Wings      2   50.00       1
# 4    Accessory                Bio Chip      2   50.00       1
# ..         ...                     ...    ...     ...     ...
# 251     Weapon             Moonslasher      1  100.00       1
# 252     Weapon               Nunchucks      5   20.00       1
# 253     Weapon                  Quiver      4   25.00       1
# 254     Weapon                  Shield     10   10.00       1
# 255     Weapon             Steel Staff      3   33.33       1
#
# [256 rows x 5 columns]

# %%
count_list.to_csv('rarity.csv')

# %% [markdown]
# ### uploading rarity file and update rarity column

# %%
df = pd.read_csv('rarity_result_uni.csv', index_col=[0])

# %%
df.head()
# Out:
#     id trait_type            value  count  rarity  weight
# 0    1  Accessory             Ring   39.0    5.13       2
# 1   10  Accessory  Silver Ear Ring    8.0   12.50       1
# 2  100  Accessory  Silver Ear Ring    8.0   12.50       1
# 3   11  Accessory       Small Ring    8.0   12.50       1
# 4   12  Accessory             Ring   39.0    5.13       2

# %%
## change the weight of the value of the trait type

# %%
val = 'Ring'
weight = 2

# %%
df.loc[df['value'] == val, 'weight'] = weight
for index in range(0, len(df)):
    if(str(df.iloc[index]['value']) == 'nan'):
        continue
    else:
        df.at[index,'count'] = count_list[count_list['value']== df.iloc[index]['value']].iloc[0][0]
        df.at[index,'rarity'] = (total/df.iloc[index]['count'])*df.iloc[index]['weight']

    
df['rarity'] = df['rarity'].astype('float64').round(2) 
df.to_csv('rarity_result_uni.csv')

# %%
## total score calculation

# %%
dfo = pd.read_csv('result_uni.csv', index_col=[0])

# %%
dfo.head()
# Out:
#                           name                description  \
# id
# 1      Uninterested Unicorn #1    Uninterested Unicorn #1
# 10    Uninterested Unicorn #10   Uninterested Unicorn #10
# 100  Uninterested Unicorn #100  Uninterested Unicorn #100
# 11    Uninterested Unicorn #11   Uninterested Unicorn #11
# 12    Uninterested Unicorn #12   Uninterested Unicorn #12
#
#                                                  image        Accessory  \
# id
# 1    https://uunicorns.mypinata.cloud/ipfs/QmdN73o6...             Ring
# 10   https://uunicorns.mypinata.cloud/ipfs/QmZRHz6s...  Silver Ear Ring
# 100  https://uunicorns.mypinata.cloud/ipfs/QmYZx7Aq...  Silver Ear Ring
# 11   https://uunicorns.mypinata.cloud/ipfs/QmYoStWc...       Small Ring
# 12   https://uunicorns.mypinata.cloud/ipfs/QmRZAjmG...             Ring
#
#     Background  Beard Body Tattoo Braid      Chest   Clan  ...          Mouth  \
# id                                                         ...
# 1       Common    NaN         NaN   NaN  Traveller    Air  ...              O
# 10      Common    NaN         NaN   NaN        NaN   Dark  ...  Droopy Tongue
# 100  Pink Fire    NaN         NaN   NaN      Mummy   Dark  ...           Lost
# 11      Common    NaN         NaN   NaN   Assassin   Fire  ...         Closed
# 12      Common  Short         NaN   NaN        NaN  Earth  ...         Closed
#
#                Neck Neck Tattoo Necklace    Pattern     Shoulder Skin Colour  \
# id
# 1     Leather Wraps         NaN      NaN        NaN  Black Pearl        Cyan
# 10              NaN         NaN      NaN  Cracked 1          NaN         Jam
# 100             NaN         NaN      NaN   Skeleton          NaN       Green
# 11   Assassin Wraps         NaN      NaN        NaN  Black Pearl        Rose
# 12              NaN         NaN      NaN        NaN          NaN        Blue
#
#     Special Tattoo     Weapon
# id
# 1       NaN    NaN     Katana
# 10      NaN    NaN        NaN
# 100     NaN    NaN        NaN
# 11      NaN  Kunai  Nunchucks
# 12      NaN  Kunai        NaN
#
# [5 rows x 30 columns]

# %%
dfr = pd.read_csv('rarity_result_uni.csv', index_col=[0])

# %%
dfr.head()
# Out:
#   trait_type                   value  count  rarity  weight
# 0  Accessory    1 Dark Caged Blinker      1   100.0       1
# 1  Accessory   1 Light Caged Blinker      4    25.0       1
# 2  Accessory  2 Light Caged Blinkers      1   100.0       1
# 3  Accessory     2 Light Eagle Wings      2    50.0       1
# 4  Accessory                Bio Chip      2    50.0       1

# %%
dfo['total_score'] = np.nan

# %%
len(dfo.columns[3:-1])
# Out:
# 27

# %%
index = 0
for row in dfo.iterrows():
    score = 0
    for col in range(3,len(dfo.columns)-1):
        if(str(row[1][col]) == 'nan'):
            continue
        else:
            col_name = dfo.columns[col]
            col_value = row[1][col]
            score = score + float(dfr.loc[(dfr.trait_type == col_name)&(dfr.value == col_value), 'rarity'])
    dfo.at[index,'total_score'] = score
    index = index+1
# Out:
# Accessory
# Ring
# Background
# Common
# Chest
# Traveller
# Clan
# Air
# Class
# Ninja
# Eye
# Purple
# Hair Colour
# Black
# Horn
# Air
# Mouth
# O
# Neck
# Leather Wraps
# Shoulder
# Black Pearl
# Skin Colour
# Cyan
# Weapon
# Katana
# Accessory
# Silver Ear Ring
# Background
# Common
# Clan
# Dark
# Class
# Zombie
# Eye
# Heterochromia
# Hair Colour
# Green
# Horn
# Zombie Cut Blood
# Mouth
# Droopy Tongue
# Pattern
# Cracked 1
# Skin Colour
# Jam
# Accessory
# Silver Ear Ring
# Background
# Pink Fire
# Chest
# Mummy
# Clan
# Dark
# Class
# Zombie
# Eye
# Socket
# Hair Colour
# Red
# Horn
# Corrupted
# Mouth
# Lost
# Pattern
# Skeleton
# Skin Colour
# Green
# Accessory
# Small Ring
# Background
# Common
# Chest
# Assassin
# Clan
# Fire
# Class
# Ninja
# Eye
# Blue
# Hair Colour
# White
# Horn
# Fire
# Mask
# Silent
# Mouth
# Closed
# Neck
# Assassin Wraps
# Shoulder
# Black Pearl
# Skin Colour
# Rose
# Tattoo
# Kunai
# Weapon
# Nunchucks
# Accessory
# Ring
# Background
# Common
# Beard
# Short
# Clan
# Earth
# Class
# Ninja
# Eye
# Blue
# Hair Colour
# Black
# Headgear
# Bandana
# Horn
# Earth
# Mark
# X
# Mouth
# Closed
# Skin Colour
# Blue
# Tattoo
# Kunai
# Accessory
# Ring
# Background
# Common
# Beard
# Short
# Chest
# Assassin
# Clan
# Air
# Class
# Ninja
# Eye
# Orange
# Hair Colour
# Black
# Horn
# Air
# Mark
# X
# Mouth
# Closed
# Neck
# Leather Wraps
# Pattern
# Light Zebra
# Shoulder
# Samurai
# Skin Colour
# Ocean
# Tattoo
# Kunai
# Accessory
# Ring
# Background
# Common
# Chest
# Red Wizard Cloak
# Clan
# Air
# Class
# Mage
# Eye
# Blue
# Hair Colour
# White
# Horn
# Air
# Mark
# Eye Rune
# Mouth
# Closed
# Pattern
# Dark Zebra
# Skin Colour
# Amethyst
# Weapon
# Air Staff
# Accessory
# Bio Chip
# Skin Colour
# Butter
# Weapon
# Shield
# Accessory
# 1 Dark Caged Blinker
# Background
# Common
# Clan
# Fire
# Class
# Knight
# Eye
# Heterochromia
# Hair Colour
# Blue
# Headgear
# Dark Maximus
# Horn
# Fire
# Mask
# Dark Oink
# Mouth
# Closed
# Skin Colour
# Blue
# Weapon
# Chopper
# Accessory
# 2 Light Eagle Wings
# Background
# Common
# Chest
# Light Knight
# Clan
# Air
# Class
# Knight
# Eye
# Green
# Hair Colour
# Blue
# Headgear
# Light T-visor
# Horn
# Air
# Mask
# Light Ironmask
# Mouth
# Closed
# Pattern
# Dark Cheetah
# Shoulder
# Light Paladin Pauldron
# Skin Colour
# Choco
# Special
# Commander Chest
# Weapon
# Chopper
# Background
# Common
# Braid
# Purple Braid
# Chest
# Grey Chainmail
# Clan
# Water
# Class
# Hunter
# Eye
# Blue
# Hair Colour
# Purple
# Headgear
# Water Green Thief
# Horn
# Water
# Mark
# Scars
# Mouth
# Closed
# Skin Colour
# Rose
# Weapon
# Bow

# %%
dfo.head()
# Out:
#                           name                description  \
# id
# 1      Uninterested Unicorn #1    Uninterested Unicorn #1
# 10    Uninterested Unicorn #10   Uninterested Unicorn #10
# 100  Uninterested Unicorn #100  Uninterested Unicorn #100
# 11    Uninterested Unicorn #11   Uninterested Unicorn #11
# 12    Uninterested Unicorn #12   Uninterested Unicorn #12
#
#                                                  image        Accessory  \
# id
# 1    https://uunicorns.mypinata.cloud/ipfs/QmdN73o6...             Ring
# 10   https://uunicorns.mypinata.cloud/ipfs/QmZRHz6s...  Silver Ear Ring
# 100  https://uunicorns.mypinata.cloud/ipfs/QmYZx7Aq...  Silver Ear Ring
# 11   https://uunicorns.mypinata.cloud/ipfs/QmYoStWc...       Small Ring
# 12   https://uunicorns.mypinata.cloud/ipfs/QmRZAjmG...             Ring
#
#     Background  Beard Body Tattoo Braid      Chest   Clan  ...  \
# id                                                         ...
# 1       Common    NaN         NaN   NaN  Traveller    Air  ...
# 10      Common    NaN         NaN   NaN        NaN   Dark  ...
# 100  Pink Fire    NaN         NaN   NaN      Mummy   Dark  ...
# 11      Common    NaN         NaN   NaN   Assassin   Fire  ...
# 12      Common  Short         NaN   NaN        NaN  Earth  ...
#
#                Neck Neck Tattoo Necklace    Pattern     Shoulder Skin Colour  \
# id
# 1     Leather Wraps         NaN      NaN        NaN  Black Pearl        Cyan
# 10              NaN         NaN      NaN  Cracked 1          NaN         Jam
# 100             NaN         NaN      NaN   Skeleton          NaN       Green
# 11   Assassin Wraps         NaN      NaN        NaN  Black Pearl        Rose
# 12              NaN         NaN      NaN        NaN          NaN        Blue
#
#     Special Tattoo     Weapon total_score
# id
# 1       NaN    NaN     Katana      157.08
# 10      NaN    NaN        NaN      157.97
# 100     NaN    NaN        NaN         NaN
# 11      NaN  Kunai  Nunchucks      373.85
# 12      NaN  Kunai        NaN      171.42
#
# [5 rows x 31 columns]

# %%
dfo.to_csv('final_df.csv')
