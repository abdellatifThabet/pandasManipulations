# %%
import os, json
import pandas as pd
import numpy as np
import glob
import re

# %% [markdown]
# ## call this function to get all your json files into a dataframe by specifying path to folder

# %%
pd.set_option('display.max_columns', None)
temp = pd.DataFrame()
def jsons_df(path_to_json):
    file_list = []
    num_files = len(glob.glob(path_to_json + "*.json"))
    print(num_files)
    for i in range(1,num_files+1):
        file_list.append(path_to_json + str(i) + '.json')
    
    data = []
    for cpt, file in enumerate(file_list):
        try:
            with open(file,'r') as f:
                sample = json.loads(f.read())
                sample['id'] = cpt+1
                data.append(sample)
        except:
            continue
        # Flattening JSON data
    normalized = pd.json_normalize(
        data, 
        record_path =['attributes'], 
        #meta=['class', 'room', ['info', 'teachers', 'math']],
        meta=['name', 'image','description','id' ],
        errors='ignore'
    )
    last_df = normalized.pivot_table(values='value', index=normalized.index, columns='trait_type', aggfunc='first')
    
    result_svs = pd.concat([normalized[['name','description','image','id']], last_df], axis=1)
    result_svs = result_svs.groupby(['name'], as_index=False).first()
    result_svs = result_svs.set_index('id')
    return result_svs

# %%
result_svs = jsons_df('json/')
# Out:
# 8888

# %%
result_uni = jsons_df('uni/uni_json/')
# Out:
# 100

# %%
result_svs.head()
# Out:
#                     name                                        description  \
# id
# 1      Sneaky Vampire #1  [Image without background](https://ipfs.io/ipf...
# 10    Sneaky Vampire #10  [Image without background](https://ipfs.io/ipf...
# 100  Sneaky Vampire #100  [Image without background](https://ipfs.io/ipf...
# 11    Sneaky Vampire #11  [Image without background](https://ipfs.io/ipf...
# 12    Sneaky Vampire #12  [Image without background](https://ipfs.io/ipf...
#
#                                                  image     Accessory  \
# id
# 1    ipfs://bafybeibltrk5hoi5p3swpiw5wnthqxh7z5xvke...  Diamond Stud
# 10   ipfs://bafybeibltrk5hoi5p3swpiw5wnthqxh7z5xvke...          None
# 100  ipfs://bafybeibltrk5hoi5p3swpiw5wnthqxh7z5xvke...      Flu Mask
# 11   ipfs://bafybeibltrk5hoi5p3swpiw5wnthqxh7z5xvke...          None
# 12   ipfs://bafybeibltrk5hoi5p3swpiw5wnthqxh7z5xvke...         Drool
#
#           Background Beard          Body          Clothes       Eyes  \
# id
# 1              Green  None  Nightcrawler   The Accountant    Demonic
# 10   Twilight Purple  None        Cyborg     Bulls Jersey       Dark
# 100           Maroon  None  Purple Count       Turtleneck       Dark
# 11           Magenta  None        Cyborg  Black Tracksuit      Black
# 12            Orange  None  Purple Count           Slayer  Bloodshot
#
#        Glasses   Hair        Hat          Head  Moon           Mouth
# id
# 1         None  Blond       None  Nightcrawler   Sun  Pierced Tongue
# 10   Eye Patch   Base    Red Cap        Cyborg  Moon          Tongue
# 100       None   Base       None  Purple Count  Moon      Gold Fangs
# 11     Glasses   Base  Red Beret        Cyborg  Moon          Tongue
# 12   Eye Patch  Green  Third Eye  Purple Count  Moon            Base

# %%
result_svs.to_csv('result_svs.csv')

# %%
result_uni.head()
# Out:
#                           name                description  \
# id
# 1      Uninterested Unicorn #1    Uninterested Unicorn #1
# 10    Uninterested Unicorn #10   Uninterested Unicorn #10
# 100  Uninterested Unicorn #100  Uninterested Unicorn #100
# 11    Uninterested Unicorn #11   Uninterested Unicorn #11
# 12    Uninterested Unicorn #12   Uninterested Unicorn #12
#
#                                                  image        Accessory  \
# id
# 1    https://uunicorns.mypinata.cloud/ipfs/QmdN73o6...             Ring
# 10   https://uunicorns.mypinata.cloud/ipfs/QmZRHz6s...  Silver Ear Ring
# 100  https://uunicorns.mypinata.cloud/ipfs/QmYZx7Aq...  Silver Ear Ring
# 11   https://uunicorns.mypinata.cloud/ipfs/QmYoStWc...       Small Ring
# 12   https://uunicorns.mypinata.cloud/ipfs/QmRZAjmG...             Ring
#
#     Background  Beard Body Tattoo Braid      Chest   Clan   Class Companion  \
# id
# 1       Common   None        None  None  Traveller    Air   Ninja      None
# 10      Common   None        None  None       None   Dark  Zombie      None
# 100  Pink Fire   None        None  None      Mummy   Dark  Zombie      None
# 11      Common   None        None  None   Assassin   Fire   Ninja      None
# 12      Common  Short        None  None       None  Earth   Ninja      None
#
#                Eye Eye Tattoo Glasses Hair Colour Headgear              Horn  \
# id
# 1           Purple       None    None       Black     None               Air
# 10   Heterochromia       None    None       Green     None  Zombie Cut Blood
# 100         Socket       None    None         Red     None         Corrupted
# 11            Blue       None    None       White     None              Fire
# 12            Blue       None    None       Black  Bandana             Earth
#
#      Mark    Mask          Mouth            Neck Neck Tattoo Necklace  \
# id
# 1    None    None              O   Leather Wraps        None     None
# 10   None    None  Droopy Tongue            None        None     None
# 100  None    None           Lost            None        None     None
# 11   None  Silent         Closed  Assassin Wraps        None     None
# 12      X    None         Closed            None        None     None
#
#        Pattern     Shoulder Skin Colour Special Tattoo     Weapon
# id
# 1         None  Black Pearl        Cyan    None   None     Katana
# 10   Cracked 1         None         Jam    None   None       None
# 100   Skeleton         None       Green    None   None       None
# 11        None  Black Pearl        Rose    None  Kunai  Nunchucks
# 12        None         None        Blue    None  Kunai       None

# %%
result_uni.to_csv('result_uni.csv')

# %%
result_js = jsons_df('json/')
# Out:
# 8888

# %%
result_js
# Out:
#                      name                                        description  \
# id
# 5304        Ancient Count  [Image without background](https://ipfs.io/ipf...
# 8065         Bat (1 of 8)  [Image without background](https://ipfs.io/ipf...
# 7491         Bat (2 of 8)  [Image without background](https://ipfs.io/ipf...
# 8078         Bat (3 of 8)  [Image without background](https://ipfs.io/ipf...
# 3693         Bat (4 of 8)  [Image without background](https://ipfs.io/ipf...
# ...                   ...                                                ...
# 999   Sneaky Vampire #999  [Image without background](https://ipfs.io/ipf...
# 3468          The Impaler  [Image without background](https://ipfs.io/ipf...
# 2173         Vampire Lord  [Image without background](https://ipfs.io/ipf...
# 604           Vampire Nun  [Image without background](https://ipfs.io/ipf...
# 7086       Vampire Slayer  [Image without background](https://ipfs.io/ipf...
#
#                                                   image Accessory Background  \
# id
# 5304  ipfs://bafybeibltrk5hoi5p3swpiw5wnthqxh7z5xvke...      None       None
# 8065  ipfs://bafybeibltrk5hoi5p3swpiw5wnthqxh7z5xvke...      None       None
# 7491  ipfs://bafybeibltrk5hoi5p3swpiw5wnthqxh7z5xvke...      None       None
# 8078  ipfs://bafybeibltrk5hoi5p3swpiw5wnthqxh7z5xvke...      None       None
# 3693  ipfs://bafybeibltrk5hoi5p3swpiw5wnthqxh7z5xvke...      None       None
# ...                                                 ...       ...        ...
# 999   ipfs://bafybeibltrk5hoi5p3swpiw5wnthqxh7z5xvke...     Drool      Green
# 3468  ipfs://bafybeibltrk5hoi5p3swpiw5wnthqxh7z5xvke...      None       None
# 2173  ipfs://bafybeibltrk5hoi5p3swpiw5wnthqxh7z5xvke...      None       None
# 604   ipfs://bafybeibltrk5hoi5p3swpiw5wnthqxh7z5xvke...      None       None
# 7086  ipfs://bafybeibltrk5hoi5p3swpiw5wnthqxh7z5xvke...      None       None
#
#      Beard          Body       Clothes     Eyes Glasses   Hair        Hat  \
# id
# 5304  None          None          None     None    None   None       None
# 8065  None          None          None     None    None   None       None
# 7491  None          None          None     None    None   None       None
# 8078  None          None          None     None    None   None       None
# 3693  None          None          None     None    None   None       None
# ...    ...           ...           ...      ...     ...    ...        ...
# 999   None  Purple Count  Bulls Jersey  Demonic    None  Green  Third Eye
# 3468  None          None          None     None    None   None       None
# 2173  None          None          None     None    None   None       None
# 604   None          None          None     None    None   None       None
# 7086  None          None          None     None    None   None       None
#
#               Head  Moon Mouth          Unique
# id
# 5304          None  None  None   Ancient Count
# 8065          None  None  None         Bathead
# 7491          None  None  None         Bathead
# 8078          None  None  None         Bathead
# 3693          None  None  None         Bathead
# ...            ...   ...   ...             ...
# 999   Purple Count  Moon  Base            None
# 3468          None  None  None     The Impaler
# 2173          None  None  None    Vampire Lord
# 604           None  None  None     Vampire Nun
# 7086          None  None  None  Vampire Slayer
#
# [8888 rows x 16 columns]

# %%
result_js.to_csv('result_js.csv')
